# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1,100)
y = np.log(x)

# %%
plt.xlabel('Size Of Dataset')
plt.ylabel('Time')
plt.title('O(log(n))')
plt.text(1,4,'Author: Jakub Záloha')
plt.plot(x,y)
plt.savefig('O(log(n))', format='png')
