# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,6)
y = 4**x

# %%
plt.xlabel('Missing Places')
plt.ylabel('Time')
plt.title('O(4^m)')
plt.text(0,4000,'Author: Jakub Záloha')
plt.plot(x,y)
current_values = plt.gca().get_yticks()
# using format string '{:.0f}' here but you can choose others
plt.grid(linestyle=':', linewidth=0.5)
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
plt.savefig('O(4^m)', format='png')
# Out:
# /var/folders/6c/26qrqsjs76v40w9p3j4xvrx40000gn/T/ipykernel_30373/669720969.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
